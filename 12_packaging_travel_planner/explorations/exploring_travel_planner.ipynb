# %% [markdown]
# # Explorations

# %%
from backend.connect_to_api import ResRobot

resrobot = ResRobot()

resrobot.access_id_from_location("Umeå")
# Out:
# Name                                               extId
# UMEÅ                                               740098065
# Umeå Centralstation                                740000190
# Umeå Busstation                                    740020461
# Umeå Östra station                                 740001581
# Umeå Vasaplan                                      740020116
# Umeå Airport                                       740025159
# Umeå Ålidhem centrum                               740023156
# Umeå Ålidhöjd                                      740045439
# Umeå Älvans väg                                    740045410
# Umeå Alviksgränd                                   740045280

# %%
resrobot.access_id_from_location("Göteborg")
# Out:
# Name                                               extId
# GÖTEBORG                                           740098001
# Göteborg Centralstation                            740000002
# Göteborg Sävenäs lokstation                        740016365
# GÖTEBORG GAMLESTADEN                               740098526
# Göteborg Korsvägen                                 740015578
# Göteborg Kungsportsplatsen                         740016358
# Göteborg Stenpiren                                 740072430
# Göteborg Eketrägatan                               740025624
# Göteborg Vårväderstorget                           740025707
# Göteborg Axel Dahlströms torg                      740025608

# %%
umea_id = 740000190
gothenburg_id = 740000002

trips = resrobot.trips(umea_id, gothenburg_id)

len(trips["Trip"])
# Out:
# 5

# %%
trips["Trip"][1]["LegList"]
# Out:
# {'Leg': [{'Origin': {'name': 'Umeå Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#     'extId': '740000190',
#     'lon': 20.26681,
#     'lat': 63.830064,
#     'routeIdx': 0,
#     'prognosisType': 'PROGNOSED',
#     'time': '14:20:00',
#     'date': '2025-01-20',
#     'minimumChangeDuration': 'PT10M'},
#    'Destination': {'name': 'Stockholm Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#     'extId': '740000001',
#     'lon': 18.058151,
#     'lat': 59.330136,
#     'routeIdx': 11,
#     'prognosisType': 'PROGNOSED',
#     'time': '20:37:00',
#     'date': '2025-01-20',
#     'minimumChangeDuration': 'PT20M'},
#    'Notes': {'Note': [{'value': 'SJ3000',
#       'key': 'V3',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'SJ3000'},
#      {'value': 'Mat 1 klass',
#       'key': 'A1',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Mat 1 klass'},
#      {'value': 'Bistrovagn',
#       'key': 'AD',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Bistrovagn'},
#      {'value': 'Obligatorisk platsbokning',
#       'key': 'AF',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Obligatorisk platsbokning'},
#      {'value': 'Rullstolslyft',
#       'key': 'AN',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Rullstolslyft'},
#      {'value': 'WiFi',
#       'key': 'AW',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'WiFi'},
#      {'value': '2 klass lugn',
#       'key': 'BL',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': '2 klass lugn'},
#      {'value': 'EU förordning 2021/782',
#       'key': 'EJ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'EU förordning 2021/782'},
#      {'value': 'Maträtt',
#       'key': 'SM',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Maträtt'},
#      {'value': '1 klass med extra komfort',
#       'key': 'SU',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': '1 klass med extra komfort'},
#      {'value': 'Kaffebuffé 1 klass',
#       'key': 'SZ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Kaffebuffé 1 klass'}]},
#    'JourneyDetailRef': {'ref': '1|68485|0|1|20012025'},
#    'JourneyStatus': 'P',
#    'Product': [{'icon': {'res': 'prod_gen'},
#      'operatorInfo': {'name': 'SJ',
#       'nameS': '74',
#       'nameN': '74',
#       'nameL': 'SJ',
#       'id': '74'},
#      'name': 'Snabbtåg 585',
#      'internalName': 'Snabbtåg 585',
#      'displayNumber': '585',
#      'num': '585',
#      'line': '585',
#      'lineId': '1074058500001',
#      'catOut': 'JST',
#      'catIn': 'JST',
#      'catCode': '1',
#      'cls': '2',
#      'catOutS': 'JST',
#      'catOutL': 'Snabbtåg',
#      'operatorCode': '74',
#      'operator': 'SJ',
#      'admin': '074___',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 11,
#      'matchId': '585;585;45205'}],
#    'Stops': {'Stop': [{'name': 'Umeå Centralstation',
#       'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#       'extId': '740000190',
#       'routeIdx': 0,
#       'lon': 20.26681,
#       'lat': 63.830064,
#       'depPrognosisType': 'PROGNOSED',
#       'depTime': '14:20:00',
#       'depDate': '2025-01-20',
#       'depDir': 'Stockholm Centralstation',
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för påstigande',
#          'key': 'text.realtime.stop.exit.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för påstigande'}]},
#       'name': 'Umeå Östra station',
#       'id': 'A=1@O=Umeå Östra station@X=20293454@Y=63817659@U=1@L=740001581@',
#       'extId': '740001581',
#       'routeIdx': 1,
#       'lon': 20.293454,
#       'lat': 63.817659,
#       'depTime': '14:25:00',
#       'depDate': '2025-01-20',
#       'alighting': False,
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Örnsköldsvik Centralstation',
#       'id': 'A=1@O=Örnsköldsvik Centralstation@X=18704305@Y=63289282@U=1@L=740001570@',
#       'extId': '740001570',
#       'routeIdx': 2,
#       'lon': 18.704305,
#       'lat': 63.289282,
#       'depTime': '15:08:00',
#       'depDate': '2025-01-20',
#       'arrTime': '15:08:00',
#       'arrDate': '2025-01-20',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Kramfors station',
#       'id': 'A=1@O=Kramfors station@X=17778182@Y=62929111@U=1@L=740000220@',
#       'extId': '740000220',
#       'routeIdx': 3,
#       'lon': 17.778182,
#       'lat': 62.929111,
#       'depTime': '15:44:00',
#       'depDate': '2025-01-20',
#       'arrTime': '15:44:00',
#       'arrDate': '2025-01-20',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Härnösand station',
#       'id': 'A=1@O=Härnösand station@X=17928635@Y=62635182@U=1@L=740000253@',
#       'extId': '740000253',
#       'routeIdx': 4,
#       'lon': 17.928635,
#       'lat': 62.635182,
#       'depTime': '16:07:00',
#       'depDate': '2025-01-20',
#       'arrTime': '16:07:00',
#       'arrDate': '2025-01-20',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Sundsvall Centralstation',
#       'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#       'extId': '740000130',
#       'routeIdx': 5,
#       'lon': 17.315633,
#       'lat': 62.386873,
#       'depTime': '17:04:00',
#       'depDate': '2025-01-20',
#       'arrTime': '16:59:00',
#       'arrDate': '2025-01-20',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Hudiksvall station',
#       'id': 'A=1@O=Hudiksvall station@X=17109034@Y=61724494@U=1@L=740000187@',
#       'extId': '740000187',
#       'routeIdx': 6,
#       'lon': 17.109034,
#       'lat': 61.724494,
#       'depTime': '18:00:00',
#       'depDate': '2025-01-20',
#       'arrTime': '18:00:00',
#       'arrDate': '2025-01-20',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Söderhamn station',
#       'id': 'A=1@O=Söderhamn station@X=17035682@Y=61299600@U=1@L=740000154@',
#       'extId': '740000154',
#       'routeIdx': 7,
#       'lon': 17.035682,
#       'lat': 61.2996,
#       'depTime': '18:28:00',
#       'depDate': '2025-01-20',
#       'arrTime': '18:28:00',
#       'arrDate': '2025-01-20',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Gävle Centralstation',
#       'id': 'A=1@O=Gävle Centralstation@X=17151221@Y=60676118@U=1@L=740000210@',
#       'extId': '740000210',
#       'routeIdx': 8,
#       'lon': 17.151221,
#       'lat': 60.676118,
#       'depTime': '19:14:00',
#       'depDate': '2025-01-20',
#       'arrTime': '19:10:00',
#       'arrDate': '2025-01-20',
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#          'key': 'text.realtime.stop.entry.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för avstigande'}]},
#       'name': 'Uppsala Centralstation',
#       'id': 'A=1@O=Uppsala Centralstation@X=17646086@Y=59858531@U=1@L=740000005@',
#       'extId': '740000005',
#       'routeIdx': 9,
#       'lon': 17.646086,
#       'lat': 59.858531,
#       'arrTime': '19:59:00',
#       'arrDate': '2025-01-20',
#       'boarding': False,
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#          'key': 'text.realtime.stop.entry.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för avstigande'}]},
#       'name': 'Arlanda Centralstation (Sigtuna kn)',
#       'id': 'A=1@O=Arlanda Centralstation (Sigtuna kn)@X=17929201@Y=59649469@U=1@L=740000556@',
#       'extId': '740000556',
#       'routeIdx': 10,
#       'lon': 17.929201,
#       'lat': 59.649469,
#       'arrTime': '20:19:00',
#       'arrDate': '2025-01-20',
#       'boarding': False,
#       'minimumChangeDuration': 'PT2H'},
#      {'name': 'Stockholm Centralstation',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'routeIdx': 11,
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'arrPrognosisType': 'PROGNOSED',
#       'arrTime': '20:37:00',
#       'arrDate': '2025-01-20',
#       'minimumChangeDuration': 'PT20M'}]},
#    'JourneyDetail': {'ref': '1|68485|0|1|20012025',
#     'dayOfOperation': '2025-01-20'},
#    'id': '0',
#    'idx': 0,
#    'name': 'Snabbtåg 585',
#    'number': '585',
#    'category': 'JST',
#    'type': 'JNY',
#    'reachable': True,
#    'waitingState': 'UNDEF',
#    'direction': 'Stockholm Centralstation',
#    'directionFlag': '1',
#    'duration': 'PT6H17M',
#    'minimumChangeDuration': 'PT20M'},
#   {'Origin': {'name': 'Stockholm Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#     'extId': '740000001',
#     'lon': 18.058151,
#     'lat': 59.330136,
#     'routeIdx': 0,
#     'prognosisType': 'PROGNOSED',
#     'time': '21:12:00',
#     'date': '2025-01-20',
#     'minimumChangeDuration': 'PT20M'},
#    'Destination': {'name': 'Göteborg Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#     'extId': '740000002',
#     'lon': 11.973479,
#     'lat': 57.708895,
#     'routeIdx': 3,
#     'prognosisType': 'PROGNOSED',
#     'time': '00:41:00',
#     'date': '2025-01-21',
#     'minimumChangeDuration': 'PT15M'},
#    'Notes': {'Note': [{'value': 'X2000',
#       'key': 'VX',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'X2000'},
#      {'value': 'Mat 1 klass',
#       'key': 'A1',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Mat 1 klass'},
#      {'value': 'Bistrovagn',
#       'key': 'AD',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Bistrovagn'},
#      {'value': 'Obligatorisk platsbokning',
#       'key': 'AF',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Obligatorisk platsbokning'},
#      {'value': 'Rullstolslyft',
#       'key': 'AN',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Rullstolslyft'},
#      {'value': 'WiFi',
#       'key': 'AW',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'WiFi'},
#      {'value': '2 klass lugn',
#       'key': 'BL',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': '2 klass lugn'},
#      {'value': 'EU förordning 2021/782',
#       'key': 'EJ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'EU förordning 2021/782'},
#      {'value': 'Maträtt',
#       'key': 'SM',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Maträtt'},
#      {'value': '1 klass med extra komfort',
#       'key': 'SU',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': '1 klass med extra komfort'},
#      {'value': 'Kaffebuffé 1 klass',
#       'key': 'SZ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Kaffebuffé 1 klass'}]},
#    'JourneyDetailRef': {'ref': '1|117328|0|1|20012025'},
#    'JourneyStatus': 'P',
#    'Product': [{'icon': {'res': 'prod_gen'},
#      'operatorInfo': {'name': 'SJ',
#       'nameS': '74',
#       'nameN': '74',
#       'nameL': 'SJ',
#       'id': '74'},
#      'name': 'Snabbtåg 451',
#      'internalName': 'Snabbtåg 451',
#      'displayNumber': '451',
#      'num': '451',
#      'line': '451',
#      'lineId': '1074045100001',
#      'catOut': 'JST',
#      'catIn': 'JST',
#      'catCode': '1',
#      'cls': '2',
#      'catOutS': 'JST',
#      'catOutL': 'Snabbtåg',
#      'operatorCode': '74',
#      'operator': 'SJ',
#      'admin': '074___',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 3,
#      'matchId': '451;451;24653'}],
#    'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'routeIdx': 0,
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'depPrognosisType': 'PROGNOSED',
#       'depTime': '21:12:00',
#       'depDate': '2025-01-20',
#       'depDir': 'Göteborg Centralstation',
#       'minimumChangeDuration': 'PT20M'},
#      {'name': 'Katrineholm Centralstation',
#       'id': 'A=1@O=Katrineholm Centralstation@X=16208324@Y=58996591@U=1@L=740000166@',
#       'extId': '740000166',
#       'routeIdx': 1,
#       'lon': 16.208324,
#       'lat': 58.996591,
#       'depTime': '22:05:00',
#       'depDate': '2025-01-20',
#       'arrTime': '22:04:00',
#       'arrDate': '2025-01-20',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Skövde Centralstation',
#       'id': 'A=1@O=Skövde Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#       'extId': '740000008',
#       'routeIdx': 2,
#       'lon': 13.853195,
#       'lat': 58.390898,
#       'depTime': '23:22:00',
#       'depDate': '2025-01-20',
#       'arrTime': '23:22:00',
#       'arrDate': '2025-01-20',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Göteborg Centralstation',
#       'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#       'extId': '740000002',
#       'routeIdx': 3,
#       'lon': 11.973479,
#       'lat': 57.708895,
#       'arrPrognosisType': 'PROGNOSED',
#       'arrTime': '00:41:00',
#       'arrDate': '2025-01-21',
#       'minimumChangeDuration': 'PT15M'}]},
#    'JourneyDetail': {'ref': '1|117328|0|1|20012025',
#     'dayOfOperation': '2025-01-20'},
#    'id': '1',
#    'idx': 1,
#    'name': 'Snabbtåg 451',
#    'number': '451',
#    'category': 'JST',
#    'type': 'JNY',
#    'reachable': True,
#    'waitingState': 'UNDEF',
#    'direction': 'Göteborg Centralstation',
#    'directionFlag': '1',
#    'duration': 'PT3H29M'}]}

# %%
import pandas as pd 

# pd.DataFrame(trips["Trip"])
legs = []

for trip in trips.get("Trip"):
    legs.append(trip.get("LegList").get("Leg"))

# Umeå -> Stockholm
legs[0][0]["Origin"], legs[0][1]["Destination"]
# Out:
# ({'name': 'Umeå Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#   'extId': '740000190',
#   'lon': 20.26681,
#   'lat': 63.830064,
#   'routeIdx': 0,
#   'prognosisType': 'PROGNOSED',
#   'time': '12:37:00',
#   'date': '2025-01-20',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Stockholm Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#   'extId': '740000001',
#   'lon': 18.058151,
#   'lat': 59.330136,
#   'routeIdx': 6,
#   'prognosisType': 'PROGNOSED',
#   'time': '19:37:00',
#   'date': '2025-01-20',
#   'minimumChangeDuration': 'PT20M'})

# %%
# Stockholm -> Göteborg
legs[0][1]["Origin"], legs[0][1]["Destination"]
# Out:
# ({'name': 'Sundsvall Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#   'extId': '740000130',
#   'lon': 17.315633,
#   'lat': 62.386873,
#   'routeIdx': 0,
#   'prognosisType': 'PROGNOSED',
#   'time': '16:04:00',
#   'date': '2025-01-20',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Stockholm Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#   'extId': '740000001',
#   'lon': 18.058151,
#   'lat': 59.330136,
#   'routeIdx': 6,
#   'prognosisType': 'PROGNOSED',
#   'time': '19:37:00',
#   'date': '2025-01-20',
#   'minimumChangeDuration': 'PT20M'})

# %%
next_available_trip = legs[0]
df = pd.DataFrame(next_available_trip)
df
# Out:
#                                               Origin  \
# 0  {'name': 'Umeå Centralstation', 'type': 'ST', ...
# 1  {'name': 'Sundsvall Centralstation', 'type': '...
# 2  {'name': 'Stockholm Centralstation', 'type': '...
#
#                                          Destination  \
# 0  {'name': 'Sundsvall Centralstation', 'type': '...
# 1  {'name': 'Stockholm Centralstation', 'type': '...
# 2  {'name': 'Göteborg Centralstation', 'type': 'S...
#
#                                                Notes  \
# 0  {'Note': [{'value': 'Endast 2 klass', 'key': '...
# 1  {'Note': [{'value': 'SJ3000', 'key': 'V3', 'ty...
# 2  {'Note': [{'value': 'X2000', 'key': 'VX', 'typ...
#
#                    JourneyDetailRef JourneyStatus  \
# 0   {'ref': '1|74812|0|1|20012025'}             P
# 1  {'ref': '1|151026|0|1|20012025'}             P
# 2  {'ref': '1|138989|0|1|20012025'}             P
#
#                                              Product  \
# 0  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 1  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 2  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
#
#                                                Stops  \
# 0  {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1  {'Stop': [{'name': 'Sundsvall Centralstation',...
# 2  {'Stop': [{'name': 'Stockholm Centralstation',...
#
#                                        JourneyDetail id  idx  \
# 0  {'ref': '1|74812|0|1|20012025', 'dayOfOperatio...  0    0
# 1  {'ref': '1|151026|0|1|20012025', 'dayOfOperati...  1    1
# 2  {'ref': '1|138989|0|1|20012025', 'dayOfOperati...  2    2
#
#                 name number category type  reachable waitingState  \
# 0  Regional Tåg 7411   7411      JRE  JNY       True        UNDEF
# 1       Snabbtåg 583    583      JST  JNY       True        UNDEF
# 2       Snabbtåg 449    449      JST  JNY       True        UNDEF
#
#                   direction directionFlag duration minimumChangeDuration
# 0  Sundsvall Centralstation             1   PT3H3M                 PT10M
# 1  Stockholm Centralstation             1  PT3H33M                 PT20M
# 2   Göteborg Centralstation             1  PT3H29M                   NaN

# %%
df_trip = df[["name", "Stops"]]
df_trip
# Out:
#                 name                                              Stops
# 0  Regional Tåg 7411  {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1       Snabbtåg 583  {'Stop': [{'name': 'Sundsvall Centralstation',...
# 2       Snabbtåg 449  {'Stop': [{'name': 'Stockholm Centralstation',...

# %%
df_trip["Stops"]
# Out:
# 0    {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1    {'Stop': [{'name': 'Sundsvall Centralstation',...
# 2    {'Stop': [{'name': 'Stockholm Centralstation',...
# Name: Stops, dtype: object

# %%
all_stops = pd.json_normalize(df["Stops"].dropna(), "Stop")
all_stops.head()
# Out:
#                                                 name  \
# 0                                Umeå Centralstation
# 1                                 Umeå Östra station
# 2            Hörnefors Resecentrum/Station (Umeå kn)
# 3  Nordmaling Resecentrum/Station (Nordmaling-AC kn)
# 4                    Husum station (Örnsköldsvik kn)
#
#                                                   id      extId  routeIdx  \
# 0  A=1@O=Umeå Centralstation@X=20266810@Y=6383006...  740000190         0
# 1  A=1@O=Umeå Östra station@X=20293454@Y=63817659...  740001581         1
# 2  A=1@O=Hörnefors Resecentrum/Station (Umeå kn)@...  740001582         2
# 3  A=1@O=Nordmaling Resecentrum/Station (Nordmali...  740001583         3
# 4  A=1@O=Husum station (Örnsköldsvik kn)@X=191557...  740001584         4
#
#          lon        lat depPrognosisType   depTime     depDate  \
# 0  20.266810  63.830064        PROGNOSED  12:37:00  2025-01-20
# 1  20.293454  63.817659              NaN  12:42:00  2025-01-20
# 2  19.908464  63.632661              NaN  12:56:00  2025-01-20
# 3  19.486285  63.578303              NaN  13:07:00  2025-01-20
# 4  19.155725  63.343909              NaN  13:21:00  2025-01-20
#
#                      depDir minimumChangeDuration alighting  \
# 0  Sundsvall Centralstation                 PT10M       NaN
# 1                       NaN                 PT10M     False
# 2                       NaN                  PT5M       NaN
# 3                       NaN                  PT5M       NaN
# 4                       NaN                 PT10M       NaN
#
#                                           Notes.Note   arrTime     arrDate  \
# 0                                                NaN       NaN         NaN
# 1  [{'value': 'Stannar endast för påstigande', 'k...       NaN         NaN
# 2                                                NaN  12:56:00  2025-01-20
# 3                                                NaN  13:07:00  2025-01-20
# 4                                                NaN  13:21:00  2025-01-20
#
#   boarding arrPrognosisType
# 0      NaN              NaN
# 1      NaN              NaN
# 2      NaN              NaN
# 3      NaN              NaN
# 4      NaN              NaN

# %%
stops = all_stops[["name", "arrTime", "arrDate", "depTime", "depDate", "lon", "lat"]]
stops
# Out:
#                                                  name   arrTime     arrDate  \
# 0                                 Umeå Centralstation       NaN         NaN
# 1                                  Umeå Östra station       NaN         NaN
# 2             Hörnefors Resecentrum/Station (Umeå kn)  12:56:00  2025-01-20
# 3   Nordmaling Resecentrum/Station (Nordmaling-AC kn)  13:07:00  2025-01-20
# 4                     Husum station (Örnsköldsvik kn)  13:21:00  2025-01-20
# 5                          Örnsköldsvik Norra station  13:33:00  2025-01-20
# 6                         Örnsköldsvik Centralstation  13:36:00  2025-01-20
# 7                                    Kramfors station  14:18:00  2025-01-20
# 8                                   Härnösand station  14:42:00  2025-01-20
# 9                                       Timrå station  15:22:00  2025-01-20
# 10                           Sundsvall Västra station  15:36:00  2025-01-20
# 11                           Sundsvall Centralstation  15:40:00  2025-01-20
# 12                           Sundsvall Centralstation       NaN         NaN
# 13                                 Hudiksvall station  17:00:00  2025-01-20
# 14                                  Söderhamn station  17:28:00  2025-01-20
# 15                               Gävle Centralstation  18:10:00  2025-01-20
# 16                             Uppsala Centralstation  18:58:00  2025-01-20
# 17                Arlanda Centralstation (Sigtuna kn)  19:19:00  2025-01-20
# 18                           Stockholm Centralstation  19:37:00  2025-01-20
# 19                           Stockholm Centralstation       NaN         NaN
# 20                         Katrineholm Centralstation  21:03:00  2025-01-20
# 21                              Skövde Centralstation  22:21:00  2025-01-20
# 22                            Göteborg Centralstation  23:41:00  2025-01-20
#
#      depTime     depDate        lon        lat
# 0   12:37:00  2025-01-20  20.266810  63.830064
# 1   12:42:00  2025-01-20  20.293454  63.817659
# 2   12:56:00  2025-01-20  19.908464  63.632661
# 3   13:07:00  2025-01-20  19.486285  63.578303
# 4   13:21:00  2025-01-20  19.155725  63.343909
# 5   13:33:00  2025-01-20  18.716108  63.303035
# 6   13:36:00  2025-01-20  18.704305  63.289282
# 7   14:18:00  2025-01-20  17.778182  62.929111
# 8   14:42:00  2025-01-20  17.928635  62.635182
# 9   15:22:00  2025-01-20  17.330546  62.486392
# 10       NaN         NaN  17.291668  62.389893
# 11       NaN         NaN  17.315633  62.386873
# 12  16:04:00  2025-01-20  17.315633  62.386873
# 13  17:00:00  2025-01-20  17.109034  61.724494
# 14  17:28:00  2025-01-20  17.035682  61.299600
# 15  18:14:00  2025-01-20  17.151221  60.676118
# 16       NaN         NaN  17.646086  59.858531
# 17       NaN         NaN  17.929201  59.649469
# 18       NaN         NaN  18.058151  59.330136
# 19  20:12:00  2025-01-20  18.058151  59.330136
# 20  21:04:00  2025-01-20  16.208324  58.996591
# 21  22:21:00  2025-01-20  13.853195  58.390898
# 22       NaN         NaN  11.973479  57.708895

# %%
stops = stops.drop_duplicates(subset="name").reset_index(drop=True)
stops
# Out:
#                                                  name   arrTime     arrDate  \
# 0                                 Umeå Centralstation       NaN         NaN
# 1                                  Umeå Östra station       NaN         NaN
# 2             Hörnefors Resecentrum/Station (Umeå kn)  12:56:00  2025-01-20
# 3   Nordmaling Resecentrum/Station (Nordmaling-AC kn)  13:07:00  2025-01-20
# 4                     Husum station (Örnsköldsvik kn)  13:21:00  2025-01-20
# 5                          Örnsköldsvik Norra station  13:33:00  2025-01-20
# 6                         Örnsköldsvik Centralstation  13:36:00  2025-01-20
# 7                                    Kramfors station  14:18:00  2025-01-20
# 8                                   Härnösand station  14:42:00  2025-01-20
# 9                                       Timrå station  15:22:00  2025-01-20
# 10                           Sundsvall Västra station  15:36:00  2025-01-20
# 11                           Sundsvall Centralstation  15:40:00  2025-01-20
# 12                                 Hudiksvall station  17:00:00  2025-01-20
# 13                                  Söderhamn station  17:28:00  2025-01-20
# 14                               Gävle Centralstation  18:10:00  2025-01-20
# 15                             Uppsala Centralstation  18:58:00  2025-01-20
# 16                Arlanda Centralstation (Sigtuna kn)  19:19:00  2025-01-20
# 17                           Stockholm Centralstation  19:37:00  2025-01-20
# 18                         Katrineholm Centralstation  21:03:00  2025-01-20
# 19                              Skövde Centralstation  22:21:00  2025-01-20
# 20                            Göteborg Centralstation  23:41:00  2025-01-20
#
#      depTime     depDate        lon        lat
# 0   12:37:00  2025-01-20  20.266810  63.830064
# 1   12:42:00  2025-01-20  20.293454  63.817659
# 2   12:56:00  2025-01-20  19.908464  63.632661
# 3   13:07:00  2025-01-20  19.486285  63.578303
# 4   13:21:00  2025-01-20  19.155725  63.343909
# 5   13:33:00  2025-01-20  18.716108  63.303035
# 6   13:36:00  2025-01-20  18.704305  63.289282
# 7   14:18:00  2025-01-20  17.778182  62.929111
# 8   14:42:00  2025-01-20  17.928635  62.635182
# 9   15:22:00  2025-01-20  17.330546  62.486392
# 10       NaN         NaN  17.291668  62.389893
# 11       NaN         NaN  17.315633  62.386873
# 12  17:00:00  2025-01-20  17.109034  61.724494
# 13  17:28:00  2025-01-20  17.035682  61.299600
# 14  18:14:00  2025-01-20  17.151221  60.676118
# 15       NaN         NaN  17.646086  59.858531
# 16       NaN         NaN  17.929201  59.649469
# 17       NaN         NaN  18.058151  59.330136
# 18  21:04:00  2025-01-20  16.208324  58.996591
# 19  22:21:00  2025-01-20  13.853195  58.390898
# 20       NaN         NaN  11.973479  57.708895

# %%
stops["time"] = stops["arrTime"].fillna(stops["depTime"])
stops["date"] = stops["arrDate"].fillna(stops["depDate"])

# %%
import folium

geographical_map = folium.Map(
    location=[stops["lat"].mean(), stops["lon"].mean()], zoom_start=5
)

for _, row in stops.iterrows():
    folium.Marker(
        location=[row["lat"], row["lon"]],
        popup=f"{row['name']}<br>{row['time']}<br>{row['date']}",
    ).add_to(geographical_map)

geographical_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2dcf829d0b7f2695971f59f15da8ed7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2dcf829d0b7f2695971f59f15da8ed7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2dcf829d0b7f2695971f59f15da8ed7 = L.map(
#                 &quot;map_f2dcf829d0b7f2695971f59f15da8ed7&quot;,
#                 {
#                     center: [61.678909333333344, 17.673342285714284],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53d79c99cf32fe929dd0c1f21eec6132 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53d79c99cf32fe929dd0c1f21eec6132.addTo(map_f2dcf829d0b7f2695971f59f15da8ed7);
#
#
#             var marker_2437482e3e1a4a096fb569683b4ffc51 = L.marker(
#                 [63.830064, 20.26681],
#                 {
# }
#             ).addTo(map_f2dcf829d0b7f2695971f59f15da8ed7);
#
#
#         var popup_0bba47974fe56d58f644baa2a23c7ac2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47ef7363ed21ac5e88ed5d004b2882af = $(`&lt;div id=&quot;html_47ef7363ed21ac5e88ed5d004b2882af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Umeå Centralstation&lt;br&gt;12:37:00&lt;br&gt;2025-01-20&lt;/div&gt;`)[0];
#                 popup_0bba47974fe56d58f644baa2a23c7ac2.setContent(html_47ef7363ed21ac5e88ed5d004b2882af);
#
#
#
#         marker_2437482e3e1a4a096fb569683b4ffc51.bindPopup(popup_0bba47974fe56d58f644baa2a23c7ac2)
#         ;
#
#
#
#
#             var marker_45cfb46a95696f32973ebcb18ef354e3 = L.marker(
#                 [63.817659, 20.293454],
#                 {
# }
#             ).addTo(map_f2dcf829d0b7f2695971f59f15da8ed7);
#
#
#         var popup_3100421d5d70605e1d3891a5111fb830 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87c300ee5ef63eee6544df8f2623f1fa = $(`&lt;div id=&quot;html_87c300ee5ef63eee6544df8f2623f1fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Umeå Östra station&lt;br&gt;12:42:00&lt;br&gt;2025-01-20&lt;/div&gt;`)[0];
#                 popup_3100421d5d70605e1d3891a5111fb830.setContent(html_87c300ee5ef63eee6544df8f2623f1fa);
#
#
#
#         marker_45cfb46a95696f32973ebcb18ef354e3.bindPopup(popup_3100421d5d70605e1d3891a5111fb830)
#         ;
#
#
#
#
#             var marker_d643ba9756ce7786e9773f4d7757e423 = L.marker(
#                 [63.632661, 19.908464],
#                 {
# }
#             ).addTo(map_f2dcf829d0b7f2695971f59f15da8ed7);
#
#
#         var popup_e7645749c12b404f57942599f05a7103 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc35dbd77679bab995eac431e2fca8ae = $(`&lt;div id=&quot;html_dc35dbd77679bab995eac431e2fca8ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hörnefors Resecentrum/Station (Umeå kn)&lt;br&gt;12:56:00&lt;br&gt;2025-01-20&lt;/div&gt;`)[0];
#                 popup_e7645749c12b404f57942599f05a7103.setContent(html_dc35dbd77679bab995eac431e2fca8ae);
#
#
#
#         marker_d643ba9756ce7786e9773f4d7757e423.bindPopup(popup_e7645749c12b404f57942599f05a7103)
#         ;
#
#
#
#
#             var marker_6a7b9e50ddc85067a2c1764f4e3a907b = L.marker(
#                 [63.578303, 19.486285],
#                 {
# }
#             ).addTo(map_f2dcf829d0b7f2695971f59f15da8ed7);
#
#
#         var popup_fdb0ca3ed6b9165f09229c733939e31c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fedf837b4e5347e0f5bb4636d2db490 = $(`&lt;div id=&quot;html_8fedf837b4e5347e0f5bb4636d2db490&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nordmaling Resecentrum/Station (Nordmaling-AC kn)&lt;br&gt;13:07:00&lt;br&gt;2025-01-20&lt;/div&gt;`)[0];
#                 popup_fdb0ca3ed6b9165f09229c733939e31c.setContent(html_8fedf837b4e5347e0f5bb4636d2db490);
#
#
#
#         marker_6a7b9e50ddc85067a2c1764f4e3a907b.bindPopup(popup_fdb0ca3ed6b9165f09229c733939e31c)
#         ;
#
#
#
#
#             var marker_3ba76674ed7d23d5b3a48309f195359e = L.marker(
#                 [63.343909, 19.155725],
#                 {
# }
#             ).addTo(map_f2dcf829d0b7f2695971f59f15da8ed7);
#
#
#         var popup_e2e1437f836579ca566607dc7d09be7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bc18d6e0402d0c2e35f58ef6c46861e = $(`&lt;div id=&quot;html_2bc18d6e0402d0c2e35f58ef6c46861e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Husum station (Örnsköldsvik kn)&lt;br&gt;13:21:00&lt;br&gt;2025-01-20&lt;/div&gt;`)[0];
#                 popup_e2e1437f836579ca566607dc7d09be7f.setContent(html_2bc18d6e0402
